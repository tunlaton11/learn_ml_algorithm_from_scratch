# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and student id below:

# %%
NAME = "Tunlaton Wongchai"
STUDENT_ID = "63070224"

# %% [markdown]
# ---

# %% [markdown]
# # 1 Digits Image Classification

# %% [markdown]
# ### 1.1 Load Digits dataset from sklearn library

# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
import sklearn
import matplotlib.pyplot as plt
from itertools import product

digits = load_digits()

X = digits['data']
y = digits['target']

SEED = 0

# %% [markdown]
# ### 1.2 Use sklearn train test split function to randomly split the dataset to training and test sets with test size = 0.3 and shuffle = True.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=SEED)

# %% [markdown]
# ### 1.3 Train Support Vector Machine (SVM) models on this dataset by using one-vs-all scheme. SVMs settings are defined as follows:
#
# (i) Kernel Function: Linear Function and (ii) C hyperparameter: $[10^{−6}, 1, 10^{+6}]$. Report the training/test accuracy and the number of iteration used by each set of parameter and discuss the results. What do you observe when the parameters are varied?

# %%
C_list = [1e-6, 1, 1e+6]

for C in C_list:
    clf = svm.SVC(C=C, decision_function_shape='ovr', random_state=SEED, kernel='linear')
    clf.fit(X_train, y_train)

    print('C: ', C)
    print(f'Train accuracy: {clf.score(X_train, y_train)}')
    print(f'Test accuracy: {clf.score(X_test, y_test)}')
    print('-'*30)
# Out:
# C:  1e-06
# Train accuracy: 0.2092283214001591
# Test accuracy: 0.17222222222222222
# ------------------------------
# C:  1
# Train accuracy: 1.0
# Test accuracy: 0.9740740740740741
# ------------------------------
# C:  1000000.0
# Train accuracy: 1.0
# Test accuracy: 0.9740740740740741
# ------------------------------

# %% [markdown]
# ### 1.4 Train SVM models on this dataset by using one-vs-all scheme. SVMs settings are defined as follows:
#
# (i) Kernel Function: Radial Basis Function (RBF), Kernel Parameter: Gamma $[10^{−6}, 1, 10^{+6}]$, and (iii) C hyperparameter: $[10^{−6}, 1, 10^{+6}]$. Report the training/test accu- racy and the number of iteration used by each combination set of parameter and discuss the results. What do you observe when the parameters are varied?

# %%
C_list = [1e-6, 1, 1e+6]
gamma_list = [1e-6, 1, 1e+6]

for C, gamma in product(C_list, gamma_list):
    clf = svm.SVC(C=C, gamma=gamma, decision_function_shape='ovr', random_state=SEED, kernel='rbf')
    clf.fit(X_train, y_train)

    print(f'C: {C} | gamma: {gamma}')
    print(f'Train accuracy: {clf.score(X_train, y_train)}')
    print(f'Test accuracy: {clf.score(X_test, y_test)}')
    print('-'*30)
# Out:
# C: 1e-06 | gamma: 1e-06
# Train accuracy: 0.2092283214001591
# Test accuracy: 0.17222222222222222
# ------------------------------
# C: 1e-06 | gamma: 1
# Train accuracy: 0.21161495624502785
# Test accuracy: 0.17222222222222222
# ------------------------------
# C: 1e-06 | gamma: 1000000.0
# Train accuracy: 0.21161495624502785
# Test accuracy: 0.08888888888888889
# ------------------------------
# C: 1 | gamma: 1e-06
# Train accuracy: 0.2092283214001591
# Test accuracy: 0.17222222222222222
# ------------------------------
# C: 1 | gamma: 1
# Train accuracy: 1.0
# Test accuracy: 0.08888888888888889
# ------------------------------
# C: 1 | gamma: 1000000.0
# Train accuracy: 1.0
# Test accuracy: 0.08888888888888889
# ------------------------------
# C: 1000000.0 | gamma: 1e-06
# Train accuracy: 1.0
# Test accuracy: 0.9740740740740741
# ------------------------------
# C: 1000000.0 | gamma: 1
# Train accuracy: 1.0
# Test accuracy: 0.08888888888888889
# ------------------------------
# ...

# %% [markdown]
# ### 1.5 Train SVM models on this dataset by using one-vs-all scheme. SVMs settings are defined as follows:
#
# (i) Kernel Function: Polynomial Function, Kernel Parameter: Degree [1–6] and coef0=0, and (iii) C hyperparameter: $[10^{−6},1,10^{+6}]$. Report the training/test accuracy and the number of iteration used by each combination set of parameter and discuss the results. What do you observe when the parameters are varied?

# %%
C_list = [1e-6, 1, 1e+6]
degree_list = list(range(1, 7))

for C, degree in product(C_list, degree_list):
    clf = svm.SVC(C=C, degree=degree, decision_function_shape='ovr', random_state=SEED, kernel='poly')
    clf.fit(X_train, y_train)

    print(f'C: {C} | degree: {degree}')
    print(f'Train accuracy: {clf.score(X_train, y_train)}')
    print(f'Test accuracy: {clf.score(X_test, y_test)}')
    print('-'*30)
# Out:
# C: 1e-06 | degree: 1
# Train accuracy: 0.2092283214001591
# Test accuracy: 0.17222222222222222
# ------------------------------
# C: 1e-06 | degree: 2
# Train accuracy: 0.21081941129673826
# Test accuracy: 0.17222222222222222
# ------------------------------
# C: 1e-06 | degree: 3
# Train accuracy: 0.21081941129673826
# Test accuracy: 0.17222222222222222
# ------------------------------
# C: 1e-06 | degree: 4
# Train accuracy: 0.21081941129673826
# Test accuracy: 0.17222222222222222
# ------------------------------
# C: 1e-06 | degree: 5
# Train accuracy: 0.2052505966587112
# Test accuracy: 0.16296296296296298
# ------------------------------
# C: 1e-06 | degree: 6
# Train accuracy: 0.18138424821002386
# Test accuracy: 0.15
# ------------------------------
# C: 1 | degree: 1
# Train accuracy: 0.9856801909307876
# Test accuracy: 0.9722222222222222
# ------------------------------
# C: 1 | degree: 2
# Train accuracy: 0.9952267303102625
# Test accuracy: 0.987037037037037
# ...

# %% [markdown]
# ### 1.6 Compare the results of the three kernels used in the previous questions. What do you observe? Are there any cases (set of parameters) that can lead model to be over-fitted? If there are, can you explain why did it happen?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ### 1.7  Find the optimal model that gives the best m-fold cross-validation accuracy on the training set and report the test accuracy. Feel free to select range and step of each parameter by yourself. Also illustrate how each parameter effects the accuracy of the model.
#
# For example (not that it's the correct version):
#
# ![SVM Accuracy](https://bit.ly/3fcngt1)

# %%
from dataclasses import dataclass
from typing import Literal, List

C_list = [10**x for x in np.arange(-6, 2, 0.2)]
kernel_list = ['linear', 'poly', 'rbf']

Kernel = Literal['linear', 'poly', 'rbf']

@dataclass
class Result:
    C:int
    kernel: Kernel
    acc: int

results = []

for C, kernel in product(C_list, kernel_list):
    clf = svm.SVC(C=C, decision_function_shape='ovr', random_state=SEED, kernel=kernel)
    result = Result(
        C=C,
        kernel=kernel,
        acc=np.mean(cross_val_score(clf, X_train, y_train, cv=5))
    )
    results.append(result)

# %%
def plot_result(results: List[Result], kernel: Kernel):
    results = [result for result in results if result.kernel == kernel]
    plt.xscale('log')
    plt.plot([r.C for r in results], [r.acc for r in results])

for kernel in kernel_list:
    plot_result(results, kernel)

plt.legend(kernel_list)
plt.show()

# %% [markdown]
# ### 1.8 Solve this problem with Logistic Regression. Similarly to the previous task, one-vs-all scheme is employed, multi class = ‘ovr’, and solver = ‘liblinear’. Observe the results and report the accuracy.

# %%
clf = LogisticRegression(random_state=SEED, multi_class='ovr', solver='liblinear')
clf.fit(X_train, y_train)
print(f'Train accuracy: {clf.score(X_train, y_train)}')
print(f'Test accuracy: {clf.score(X_test, y_test)}')
# Out:
# Train accuracy: 0.9976133651551312
# Test accuracy: 0.9518518518518518

# %% [markdown]
# ### 1.9 Compare the results obtained by Logistic Regression to SVM with all three kernels. Observe and discuss on the results. If the results obtained from Logistic Regression are not inline with SVM with kernels, how will you solve the problem? Explain why the results of SVM and Logistic Regression should be inlined?

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# # 2 Iris Classification

# %% [markdown]
# ### 2.1 Load Iris dataset from sklearn library

# %%
iris = sklearn.datasets.load_iris()
iris['target_names']
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# ### 2.2 Define Setal Length (cm), Setal Width (cm),petal length (cm) and petal width (cm) as X, Label—0 (Setosa), 1 (Versicolor) and 2 (Virginica) as y

# %%
data_idx = np.where(np.logical_or(iris['target'] == 0, iris['target']==1))[0]

# X = Sepal Length (cm), Sepal Width (cm)
X = iris['data'][data_idx, :]

# y = Setosa, Versicolor
y = iris['target'][data_idx]

# %% [markdown]
# ### 2.3 Use sklearn train test split function to randomly split the dataset to training and test sets with test size = 0.3 and shuffle = True.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=SEED)

# %% [markdown]
# ### 2.4 Train SVM models on this dataset by using one-vs-all scheme. Linear kernel is employed and C is set to 1. Observe and report the results. In addition, plot the feature importance of each feature obtained by SVM (weights that correspond to all features). Discuss on what you have observed. Can we illustrate feature importance from SVM with other kernels (i.e., RBF, Polynomial).
#
# For example (not that it's the correct version):
#
# ![Importance](https://bit.ly/3fejuPx)

# %%
clf = svm.SVC(decision_function_shape='ovr', random_state=SEED, kernel='linear')
clf.fit(X_train, y_train)

print(f'Train accuracy: {clf.score(X_train, y_train)}')
print(f'Test accuracy: {clf.score(X_test, y_test)}')
# Out:
# Train accuracy: 1.0
# Test accuracy: 1.0

# %%
def feature_importance(coef, names):
    importance, name = zip(*sorted(zip(coef, names)))
    plt.barh(range(len(names)), importance, align='center')
    plt.yticks(range(len(names)), names)
    plt.show()

feature_importance(clf.coef_[0], iris['feature_names'])

# %% [markdown]
# YOUR ANSWER HERE
